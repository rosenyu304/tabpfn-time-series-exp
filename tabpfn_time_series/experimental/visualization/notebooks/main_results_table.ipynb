# %%
import pandas as pd
from pathlib import Path

REPO_ROOT = Path.cwd().parent.parent.parent.parent
RESULTS_PATH = REPO_ROOT / "gift_eval" / "submission" / "all_results.csv"
EXT_RESULTS_ROOT_DIR = REPO_ROOT / "tabpfn_time_series" / "experimental" / "visualization" / "gift-eval-ext-results"

df = pd.read_csv(RESULTS_PATH)

# %%
df.head()
# Out:
#                             dataset      model  eval_metrics/MSE[mean]  \
# 0    bitbrains_fast_storage/5T/long  TabPFN-TS            5.094671e+06
# 1  bitbrains_fast_storage/5T/medium  TabPFN-TS            4.622063e+06
# 2   bitbrains_fast_storage/5T/short  TabPFN-TS            2.246919e+06
# 3    bitbrains_fast_storage/H/short  TabPFN-TS            3.140360e+06
# 4             bitbrains_rnd/5T/long  TabPFN-TS            2.963662e+06
#
#    eval_metrics/MSE[0.5]  eval_metrics/MAE[0.5]  eval_metrics/MASE[0.5]  \
# 0           5.094671e+06             483.162473                1.152664
# 1           4.622063e+06             441.637621                1.307634
# 2           2.246919e+06             263.976427                0.998051
# 3           3.140360e+06             318.895975                1.184095
# 4           2.963662e+06             265.860295                3.874638
#
#    eval_metrics/MAPE[0.5]  eval_metrics/sMAPE[0.5]  eval_metrics/MSIS  \
# 0                6.841835                 0.805314          70.219287
# 1                6.807940                 0.805071          98.995552
# 2                4.243834                 0.746523          83.528590
# 3                4.487001                 0.558861          23.623996
# 4                4.921696                 0.749694         253.212313
#
#    eval_metrics/RMSE[mean]  eval_metrics/NRMSE[mean]  eval_metrics/ND[0.5]  \
# 0              2257.137830                  5.964941              1.276854
# 1              2149.898456                  6.531985              1.341817
# 2              1498.972668                  4.706403              0.828821
# 3              1772.106184                  5.051078              0.908957
# 4              1721.528843                  6.594789              1.018451
#
#    eval_metrics/mean_weighted_sum_quantile_loss        domain  num_variates
# 0                                      0.885016  Web/CloudOps             2
# 1                                      0.948632  Web/CloudOps             2
# 2                                      0.661819  Web/CloudOps             2
# 3                                      0.669886  Web/CloudOps             2
# 4                                      0.819124  Web/CloudOps             2

# %%
# Get all dataset names
import pandas as pd

# Recursively find all "all_results.csv" files under the EXTERNAL_RESULTS_ROOT_DIR
all_results_files = list(EXT_RESULTS_ROOT_DIR.glob("**/all_results.csv"))

# Read and concatenate all the CSV files
all_results_dfs = []
for file_path in all_results_files:
    single_df = pd.read_csv(file_path)
    all_results_dfs.append(single_df)

# Combine all dataframes if any were successfully read
if all_results_dfs:
    combined_results_df = pd.concat(all_results_dfs, ignore_index=True)
    print(f"Found and combined {len(all_results_dfs)} 'all_results.csv' files")
else:
    combined_results_df = pd.DataFrame()
    print("No 'all_results.csv' files found")

print("combined_results_df.shape", combined_results_df.shape)
# Out:
# Found and combined 10 'all_results.csv' files
# combined_results_df.shape (970, 15)

# %%
all_df = pd.concat([df, combined_results_df])

# %%
all_df.head()
# Out:
#                             dataset      model  eval_metrics/MSE[mean]  \
# 0    bitbrains_fast_storage/5T/long  TabPFN-TS            5.094671e+06
# 1  bitbrains_fast_storage/5T/medium  TabPFN-TS            4.622063e+06
# 2   bitbrains_fast_storage/5T/short  TabPFN-TS            2.246919e+06
# 3    bitbrains_fast_storage/H/short  TabPFN-TS            3.140360e+06
# 4             bitbrains_rnd/5T/long  TabPFN-TS            2.963662e+06
#
#    eval_metrics/MSE[0.5]  eval_metrics/MAE[0.5]  eval_metrics/MASE[0.5]  \
# 0           5.094671e+06             483.162473                1.152664
# 1           4.622063e+06             441.637621                1.307634
# 2           2.246919e+06             263.976427                0.998051
# 3           3.140360e+06             318.895975                1.184095
# 4           2.963662e+06             265.860295                3.874638
#
#    eval_metrics/MAPE[0.5]  eval_metrics/sMAPE[0.5]  eval_metrics/MSIS  \
# 0                6.841835                 0.805314          70.219287
# 1                6.807940                 0.805071          98.995552
# 2                4.243834                 0.746523          83.528590
# 3                4.487001                 0.558861          23.623996
# 4                4.921696                 0.749694         253.212313
#
#    eval_metrics/RMSE[mean]  eval_metrics/NRMSE[mean]  eval_metrics/ND[0.5]  \
# 0              2257.137830                  5.964941              1.276854
# 1              2149.898456                  6.531985              1.341817
# 2              1498.972668                  4.706403              0.828821
# 3              1772.106184                  5.051078              0.908957
# 4              1721.528843                  6.594789              1.018451
#
#    eval_metrics/mean_weighted_sum_quantile_loss        domain  num_variates
# 0                                      0.885016  Web/CloudOps           2.0
# 1                                      0.948632  Web/CloudOps           2.0
# 2                                      0.661819  Web/CloudOps           2.0
# 3                                      0.669886  Web/CloudOps           2.0
# 4                                      0.819124  Web/CloudOps           2.0

# %%
processed_df = all_df.copy()
processed_df["dataset_name"] = processed_df["dataset"].apply(lambda x: x.split("/")[0])
processed_df["freq"] = processed_df["dataset"].apply(lambda x: x.split("/")[1])
processed_df["term"] = processed_df["dataset"].apply(lambda x: x.split("/")[2])

model_type_mapping = {}
for model_type, models in {
    "Tabular Foundation Model": ["TabPFN-TS"],
    "Time-Series Foundation Model": ["timesfm_2_0_500m", "chronos_bolt_base", "chronos-bolt-small", "chronos-bolt-tiny"],
    "Deep Learning Time-Series Model": ["DeepAR", "TFT", "PatchTST"],
    "Statistical Time-Series Model": ["Auto_Theta", "Auto_Arima", "Seasonal_Naive"],
}.items():
    for model in models:
        model_type_mapping[model] = model_type

processed_df["model_type"] = processed_df["model"].map(model_type_mapping)


for col in [
    "dataset_name",
    "freq",
    "term",
]:
    assert processed_df[col].notna().all(), f"Found NaN values in the {col} column"

# %%
processed_df.head()
# Out:
#                             dataset      model  eval_metrics/MSE[mean]  \
# 0    bitbrains_fast_storage/5T/long  TabPFN-TS            5.094671e+06
# 1  bitbrains_fast_storage/5T/medium  TabPFN-TS            4.622063e+06
# 2   bitbrains_fast_storage/5T/short  TabPFN-TS            2.246919e+06
# 3    bitbrains_fast_storage/H/short  TabPFN-TS            3.140360e+06
# 4             bitbrains_rnd/5T/long  TabPFN-TS            2.963662e+06
#
#    eval_metrics/MSE[0.5]  eval_metrics/MAE[0.5]  eval_metrics/MASE[0.5]  \
# 0           5.094671e+06             483.162473                1.152664
# 1           4.622063e+06             441.637621                1.307634
# 2           2.246919e+06             263.976427                0.998051
# 3           3.140360e+06             318.895975                1.184095
# 4           2.963662e+06             265.860295                3.874638
#
#    eval_metrics/MAPE[0.5]  eval_metrics/sMAPE[0.5]  eval_metrics/MSIS  \
# 0                6.841835                 0.805314          70.219287
# 1                6.807940                 0.805071          98.995552
# 2                4.243834                 0.746523          83.528590
# 3                4.487001                 0.558861          23.623996
# 4                4.921696                 0.749694         253.212313
#
#    eval_metrics/RMSE[mean]  eval_metrics/NRMSE[mean]  eval_metrics/ND[0.5]  \
# 0              2257.137830                  5.964941              1.276854
# 1              2149.898456                  6.531985              1.341817
# 2              1498.972668                  4.706403              0.828821
# 3              1772.106184                  5.051078              0.908957
# 4              1721.528843                  6.594789              1.018451
#
#    eval_metrics/mean_weighted_sum_quantile_loss        domain  num_variates  \
# 0                                      0.885016  Web/CloudOps           2.0
# 1                                      0.948632  Web/CloudOps           2.0
# 2                                      0.661819  Web/CloudOps           2.0
# 3                                      0.669886  Web/CloudOps           2.0
# 4                                      0.819124  Web/CloudOps           2.0
#
#              dataset_name freq    term                model_type
# 0  bitbrains_fast_storage   5T    long  Tabular Foundation Model
# 1  bitbrains_fast_storage   5T  medium  Tabular Foundation Model
# 2  bitbrains_fast_storage   5T   short  Tabular Foundation Model
# 3  bitbrains_fast_storage    H   short  Tabular Foundation Model
# 4           bitbrains_rnd   5T    long  Tabular Foundation Model

# %%
processed_df.model.unique()
# Out:
# array(['TabPFN-TS', 'Seasonal_Naive', 'TFT', 'timesfm_2_0_500m',
#        'PatchTST', 'Auto_Theta', 'Auto_Arima', 'DeepAR',
#        'chronos-bolt-tiny', 'chronos-bolt-small', 'chronos_bolt_base'],
#       dtype=object)

# %%
model_name_order = [
    ("TabPFN-TS", "TabPFN-TS"),
    ("timesfm_2_0_500m", "TimesFM2.0-500M"),
    ("chronos_bolt_base", "Chronos-Bolt Base"),
    ("chronos-bolt-small", "Chronos-Bolt Small"),
    ("chronos-bolt-tiny", "Chronos-Bolt Tiny"),
    ("DeepAR", "DeepAR"),
    ("PatchTST", "PatchTST"),
    ("TFT", "TFT"),
    ("Auto_Arima", "AutoARIMA"),
    ("Auto_Theta", "AutoTheta"),
    ("Seasonal_Naive", "Seasonal Naive"),
]

model_type_order = [
    "Tabular Foundation Model",
    "Time-Series Foundation Model",
    "Deep Learning Time-Series Model",
    "Statistical Time-Series Model",
]

# %%
# Group by dataset_name, freq, term and model
# Calculate mean values for MASE and wQL metrics
grouped_df = processed_df.groupby(['dataset_name', 'freq', 'term', 'model']).agg({
    'eval_metrics/MASE[0.5]': 'mean',
    'eval_metrics/mean_weighted_sum_quantile_loss': 'mean',
    'model_type': 'first'  # Get the model_type for each group
}).reset_index()

# Create a mapping dictionary from model_name_order
model_mapping = {old: new for old, new in model_name_order}

# Apply the mapping to the model column
grouped_df['display_model'] = grouped_df['model'].map(model_mapping)

# Create a hierarchical column structure with model_type as the top level
model_type_groups = {}
for model_name, display_name in model_name_order:
    model_type = model_type_mapping.get(model_name)
    if model_type not in model_type_groups:
        model_type_groups[model_type] = []
    model_type_groups[model_type].append(display_name)

# Create a categorical type for model_type with the specified order
grouped_df['model_type'] = pd.Categorical(
    grouped_df['model_type'], 
    categories=model_type_order, 
    ordered=True
)

# Sort the DataFrame by model_type to ensure consistent ordering
grouped_df = grouped_df.sort_values(['model_type', 'model'])

# Rename columns for display
grouped_df = grouped_df.rename(columns={
    'dataset_name': 'Dataset',
    'freq': 'Freq.',
    'term': 'Term'
})

# Pivot the table to get models as columns
mase_table = grouped_df.pivot_table(
    index=['Dataset', 'Freq.', 'Term'],
    columns=['model_type', 'display_model'],
    values='eval_metrics/MASE[0.5]'
)

wql_table = grouped_df.pivot_table(
    index=['Dataset', 'Freq.', 'Term'],
    columns=['model_type', 'display_model'],
    values='eval_metrics/mean_weighted_sum_quantile_loss'
)

# Function to format and bold minimum values in each row
def format_with_bold_min(df):
    formatted_df = df.copy()
    for idx in formatted_df.index:
        row = formatted_df.loc[idx]
        min_val = row.min()
        for col in formatted_df.columns:
            val = row[col]
            if val == min_val:
                formatted_df.loc[idx, col] = f"\\textbf{{{val:.3f}}}"
            else:
                formatted_df.loc[idx, col] = f"{val:.3f}"
    return formatted_df

# Apply formatting with bold minimum values
mase_table_formatted = format_with_bold_min(mase_table)
wql_table_formatted = format_with_bold_min(wql_table)

# Modify column names to include rotatebox for LaTeX
def add_rotatebox_to_columns(df):
    new_columns = df.columns.to_flat_index()
    rotated_columns = []
    
    for col in new_columns:
        model_type, model_name = col
        # Apply rotatebox to the model name (second level)
        rotated_model_name = f"\\rotatebox{{45}}{{{model_name}}}"
        rotated_columns.append((model_type, rotated_model_name))
    
    return pd.MultiIndex.from_tuples(rotated_columns, names=df.columns.names)

# Apply rotatebox to column names
mase_table_formatted.columns = add_rotatebox_to_columns(mase_table_formatted)
wql_table_formatted.columns = add_rotatebox_to_columns(wql_table_formatted)

# Generate LaTeX tables
mase_latex = mase_table_formatted.to_latex(
    multicolumn=True,
    multicolumn_format='c',
    bold_rows=False,
    longtable=False,
    escape=False,
)

wql_latex = wql_table_formatted.to_latex(
    multicolumn=True,
    multicolumn_format='c',
    bold_rows=False,
    longtable=False,
    escape=False,
)

# print("MASE Table LaTeX:")
# print(mase_latex)
# print("\nwQL Table LaTeX:")
print(wql_latex)

# For display in the notebook, we need a different approach
def highlight_min_display(s):
    is_min = s == s.min()
    return ['font-weight: bold' if v else '' for v in is_min]

# Custom CSS to rotate only the model names (second level headers) by 45 degrees
custom_styles = [
    # Target only the second level of column headers (model names)
    {'selector': 'th.col_heading.level1', 'props': [('transform', 'rotate(-45deg)'), 
                                                   ('vertical-align', 'bottom'),
                                                   ('padding-left', '10px'),
                                                   ('padding-right', '10px'),
                                                   ('height', '80px')]},
    # Keep the first level headers (model_type) horizontal
    {'selector': 'th.col_heading.level0', 'props': [('text-align', 'center')]},
    # Keep the row headers (Dataset, Freq, Term) normal
    {'selector': 'th.row_heading', 'props': [('transform', 'none')]}
]

# Display the tables in the notebook with bold minimum values and rotated model names
# print("MASE Table:")
display(mase_table.style.format("{:.3f}")
       .apply(highlight_min_display, axis=1)
       .set_table_styles(custom_styles))

# print("\nwQL Table:")
display(wql_table.style.format("{:.3f}")
       .apply(highlight_min_display, axis=1)
       .set_table_styles(custom_styles))
# Out:
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.153' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.948}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"\\textbf{{{val:.3f}}}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.953' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.994' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.980' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '7.330' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.140' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.210' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.610' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.885' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.748' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.753' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.750' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.908' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.010' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:62: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '\textbf{0.669}' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"\\textbf{{{val:.3f}}}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.734' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.290' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# /tmp/ipykernel_1369490/1314536403.py:64: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '1.360' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   formatted_df.loc[idx, col] = f"{val:.3f}"
# \begin{tabular}{llllllllllllll}
# \toprule
#  &  & model_type & Tabular Foundation Model & \multicolumn{4}{c}{Time-Series Foundation Model} & \multicolumn{3}{c}{Deep Learning Time-Series Model} & \multicolumn{3}{c}{Statistical Time-Series Model} \\
#  &  & display_model & \rotatebox{45}{TabPFN-TS} & \rotatebox{45}{Chronos-Bolt Base} & \rotatebox{45}{Chronos-Bolt Small} & \rotatebox{45}{Chronos-Bolt Tiny} & \rotatebox{45}{TimesFM2.0-500M} & \rotatebox{45}{DeepAR} & \rotatebox{45}{PatchTST} & \rotatebox{45}{TFT} & \rotatebox{45}{AutoARIMA} & \rotatebox{45}{AutoTheta} & \rotatebox{45}{Seasonal Naive} \\
# Dataset & Freq. & Term &  &  &  &  &  &  &  &  &  &  &  \\
# \midrule
# \multirow[t]{4}{*}{bitbrains_fast_storage} & \multirow[t]{3}{*}{5T} & long & 0.885 & 0.748 & 0.753 & 0.750 & 0.908 & 1.010 & \textbf{0.669} & 0.734 & 1.290 & 1.360 & 1.290 \\
#  &  & medium & 0.949 & 0.755 & 0.867 & 0.814 & 0.881 & 0.990 & 0.642 & \textbf{0.610} & 1.270 & 1.450 & 1.270 \\
#  &  & short & 0.662 & 0.454 & 0.435 & \textbf{0.420} & 0.447 & 0.493 & 0.471 & 0.451 & 1.210 & 0.731 & 1.210 \\
# \cline{2-14}
#  & H & short & 0.670 & 0.774 & 0.589 & 0.593 & 0.688 & 0.778 & \textbf{0.549} & 0.595 & 0.844 & 1.150 & 1.080 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{4}{*}{bitbrains_rnd} & \multirow[t]{3}{*}{5T} & long & 0.819 & 0.756 & 0.756 & 0.917 & 0.706 & 0.672 & 0.664 & \textbf{0.624} & 1.290 & 1.600 & 1.290 \\
#  &  & medium & 0.819 & \textbf{0.605} & 0.792 & 0.697 & 0.727 & 0.647 & 0.620 & 0.628 & 1.260 & 1.470 & 1.260 \\
#  &  & short & 0.608 & \textbf{0.438} & 0.453 & 0.482 & 0.461 & 0.557 & 0.474 & 0.486 & 1.100 & 0.741 & 1.100 \\
# \cline{2-14}
#  & H & short & 0.742 & 0.624 & 0.623 & 0.604 & 0.649 & \textbf{0.585} & 0.603 & 0.650 & 0.874 & 1.380 & 1.300 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{3}{*}{bizitobs_application} & \multirow[t]{3}{*}{10S} & long & 0.049 & 0.109 & 0.092 & 0.137 & 0.057 & 0.083 & 0.054 & 0.056 & 0.973 & \textbf{0.035} & 0.973 \\
#  &  & medium & 0.041 & 0.104 & 0.085 & 0.115 & 0.033 & 0.053 & 0.047 & 0.047 & 0.042 & \textbf{0.024} & 0.042 \\
#  &  & short & 0.015 & 0.054 & 0.035 & 0.070 & 0.014 & 0.064 & 0.022 & 0.090 & 0.035 & \textbf{0.010} & 0.035 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{6}{*}{bizitobs_l2c} & \multirow[t]{3}{*}{5T} & long & \textbf{0.306} & 0.738 & 0.790 & 0.722 & 0.748 & 0.719 & 0.324 & 0.472 & 0.674 & 0.632 & 0.674 \\
#  &  & medium & \textbf{0.261} & 0.445 & 0.462 & 0.420 & 0.529 & 0.589 & 0.332 & 0.346 & 0.530 & 0.415 & 0.530 \\
#  &  & short & 0.084 & 0.074 & \textbf{0.073} & 0.075 & 0.084 & 0.179 & 0.074 & 0.077 & 0.262 & 0.080 & 0.262 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.292 & \textbf{0.278} & 0.295 & 0.306 & 0.728 & 0.338 & 0.291 & 0.286 & 0.787 & 0.819 & 1.820 \\
#  &  & medium & \textbf{0.237} & 0.254 & 0.285 & 0.304 & 0.640 & 0.345 & 0.263 & 0.345 & 0.813 & 0.892 & 1.420 \\
#  &  & short & 0.210 & \textbf{0.189} & 0.204 & 0.203 & 0.345 & 0.789 & 0.217 & 0.401 & 0.547 & 0.507 & 0.536 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{3}{*}{bizitobs_service} & \multirow[t]{3}{*}{10S} & long & \textbf{0.052} & 0.113 & 0.095 & 0.133 & 0.062 & 0.070 & 0.057 & 0.056 & 0.056 & 0.052 & 0.056 \\
#  &  & medium & 0.041 & 0.096 & 0.081 & 0.113 & 0.038 & 0.044 & 0.045 & 0.044 & 0.049 & \textbf{0.027} & 0.049 \\
#  &  & short & 0.019 & 0.051 & 0.031 & 0.065 & 0.015 & 0.032 & 0.025 & 0.025 & 0.040 & \textbf{0.013} & 0.040 \\
# \cline{1-14} \cline{2-14}
# car_parts & M & short & 0.970 & 0.995 & 1.007 & 1.001 & 1.046 & 0.953 & 1.000 & \textbf{0.890} & 1.290 & 1.340 & 1.720 \\
# \cline{1-14} \cline{2-14}
# covid_deaths & D & short & 0.041 & 0.047 & 0.043 & 0.067 & 0.062 & 0.177 & 0.067 & 0.037 & \textbf{0.030} & 0.095 & 0.125 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{8}{*}{electricity} & \multirow[t]{3}{*}{15T} & long & \textbf{0.081} & 0.084 & 0.086 & 0.092 & 0.083 & 0.155 & 0.081 & 0.084 & 0.129 & 0.401 & 0.129 \\
#  &  & medium & 0.083 & 0.083 & 0.087 & 0.089 & \textbf{0.080} & 0.119 & 0.086 & 0.094 & 0.124 & 0.328 & 0.124 \\
#  &  & short & 0.097 & 0.082 & 0.082 & 0.086 & \textbf{0.079} & 0.152 & 0.134 & 0.184 & 0.165 & 0.140 & 0.165 \\
# \cline{2-14}
#  & D & short & 0.063 & \textbf{0.055} & 0.058 & 0.057 & 0.060 & 0.078 & 0.083 & 0.084 & 0.083 & 0.088 & 0.122 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.108 & 0.098 & 0.102 & 0.102 & \textbf{0.089} & 0.176 & 0.104 & 0.094 & 0.190 & 0.300 & 0.190 \\
#  &  & medium & 0.088 & 0.081 & 0.084 & 0.092 & \textbf{0.073} & 0.454 & 0.081 & 0.091 & 0.156 & 0.254 & 0.156 \\
#  &  & short & 0.072 & 0.064 & 0.067 & 0.072 & \textbf{0.054} & 0.094 & 0.079 & 0.089 & 0.109 & 0.177 & 0.109 \\
# \cline{2-14}
#  & W & short & 0.055 & 0.047 & 0.048 & \textbf{0.047} & 0.049 & 0.092 & 0.095 & 0.107 & 0.100 & 0.101 & 0.099 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{8}{*}{ett1} & \multirow[t]{3}{*}{15T} & long & 0.259 & 0.298 & 0.296 & 0.332 & 0.283 & 2.220 & \textbf{0.247} & 0.280 & 0.396 & 1.390 & 0.396 \\
#  &  & medium & 0.253 & 0.281 & 0.288 & 0.299 & 0.278 & 0.315 & 0.250 & \textbf{0.247} & 0.352 & 1.130 & 0.352 \\
#  &  & short & 0.167 & \textbf{0.158} & 0.169 & 0.179 & 0.168 & 0.320 & 0.191 & 0.245 & 0.241 & 0.410 & 0.241 \\
# \cline{2-14}
#  & D & short & 0.298 & 0.287 & 0.283 & 0.301 & 0.281 & 0.293 & 0.304 & 0.330 & \textbf{0.279} & 0.341 & 0.515 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & \textbf{0.295} & 0.311 & 0.337 & 0.317 & 0.310 & 0.469 & 0.297 & 0.313 & 0.430 & 1.940 & 0.616 \\
#  &  & medium & 0.283 & 0.303 & 0.295 & 0.280 & 0.282 & 0.535 & \textbf{0.273} & 0.316 & 0.384 & 1.650 & 0.540 \\
#  &  & short & 0.194 & \textbf{0.181} & 0.189 & 0.195 & 0.192 & 0.233 & 0.190 & 0.199 & 0.223 & 0.668 & 0.250 \\
# \cline{2-14}
#  & W & short & 0.284 & 0.296 & 0.293 & 0.275 & \textbf{0.272} & 0.686 & 0.323 & 0.406 & 0.305 & 0.319 & 0.338 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{8}{*}{ett2} & \multirow[t]{3}{*}{15T} & long & 0.101 & 0.111 & 0.118 & 0.119 & 0.106 & 0.304 & \textbf{0.098} & 0.109 & 0.165 & 0.169 & 0.165 \\
#  &  & medium & 0.100 & 0.110 & 0.119 & 0.113 & 0.105 & 0.258 & \textbf{0.094} & 0.104 & 0.143 & 0.150 & 0.143 \\
#  &  & short & 0.073 & 0.067 & 0.070 & 0.070 & \textbf{0.065} & 0.378 & 0.076 & 0.081 & 0.096 & 0.077 & 0.096 \\
# \cline{2-14}
#  & D & short & 0.126 & 0.094 & \textbf{0.091} & 0.095 & 0.108 & 0.207 & 0.131 & 0.096 & 0.125 & 0.164 & 0.205 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.139 & \textbf{0.117} & 0.121 & 0.124 & 0.125 & 0.196 & 0.130 & 0.138 & 0.272 & 0.336 & 0.287 \\
#  &  & medium & 0.121 & 0.115 & 0.118 & 0.116 & \textbf{0.110} & 0.281 & 0.125 & 0.122 & 0.245 & 0.284 & 0.241 \\
#  &  & short & 0.073 & \textbf{0.063} & 0.065 & 0.065 & 0.066 & 0.122 & 0.074 & 0.078 & 0.089 & 0.102 & 0.094 \\
# \cline{2-14}
#  & W & short & 0.099 & \textbf{0.088} & 0.094 & 0.095 & 0.110 & 0.728 & 0.142 & 0.160 & 0.136 & 0.160 & 0.169 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{2}{*}{hierarchical_sales} & D & short & 0.592 & \textbf{0.576} & 0.582 & 0.581 & 0.576 & 0.600 & 0.590 & 0.600 & 0.735 & 0.967 & 2.360 \\
# \cline{2-14}
#  & W & short & 0.345 & 0.353 & 0.354 & 0.353 & \textbf{0.330} & 0.379 & 0.358 & 0.382 & 0.485 & 0.474 & 1.030 \\
# \cline{1-14} \cline{2-14}
# hospital & M & short & 0.054 & 0.057 & 0.058 & 0.059 & \textbf{0.050} & 0.062 & 0.064 & 0.058 & 0.060 & 0.055 & 0.062 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{7}{*}{jena_weather} & \multirow[t]{3}{*}{10T} & long & 0.053 & 0.064 & 0.063 & 0.079 & \textbf{0.035} & 0.143 & 0.066 & 0.052 & 0.304 & 0.424 & 0.304 \\
#  &  & medium & 0.054 & 0.057 & 0.060 & 0.068 & \textbf{0.031} & 0.073 & 0.065 & 0.052 & 0.277 & 0.350 & 0.277 \\
#  &  & short & 0.034 & 0.033 & 0.037 & 0.042 & \textbf{0.016} & 0.063 & 0.064 & 0.069 & 0.155 & 0.130 & 0.155 \\
# \cline{2-14}
#  & D & short & 0.047 & \textbf{0.045} & 0.047 & 0.047 & 0.058 & 0.062 & 0.053 & 0.069 & 0.080 & 0.082 & 0.297 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.103 & \textbf{0.062} & 0.068 & 0.066 & 0.068 & 0.197 & 0.076 & 0.090 & 0.230 & 1.290 & 0.598 \\
#  &  & medium & 0.058 & \textbf{0.054} & 0.058 & 0.058 & 0.066 & 0.078 & 0.069 & 0.073 & 0.211 & 0.832 & 0.486 \\
#  &  & short & \textbf{0.042} & 0.042 & 0.043 & 0.042 & 0.045 & 0.699 & 0.050 & 0.048 & 0.143 & 0.296 & 0.173 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{4}{*}{kdd_cup_2018} & D & short & \textbf{0.362} & 0.372 & 0.373 & 0.365 & 0.378 & 0.383 & 0.401 & 0.380 & 0.393 & 0.459 & 0.888 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.478 & \textbf{0.300} & 0.419 & 0.472 & 0.518 & 1.090 & 0.477 & 0.503 & 1.050 & 0.970 & 1.250 \\
#  &  & medium & 0.450 & \textbf{0.301} & 0.364 & 0.416 & 0.466 & 0.442 & 0.442 & 0.472 & 0.851 & 0.791 & 0.949 \\
#  &  & short & 0.418 & \textbf{0.246} & 0.267 & 0.313 & 0.376 & 0.517 & 0.457 & 0.467 & 0.559 & 0.531 & 0.559 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{7}{*}{loop_seattle} & \multirow[t]{3}{*}{5T} & long & 0.090 & 0.129 & 0.125 & 0.121 & 0.114 & 0.184 & 0.095 & \textbf{0.088} & 0.137 & 0.231 & 0.137 \\
#  &  & medium & \textbf{0.087} & 0.116 & 0.119 & 0.116 & 0.110 & 0.118 & 0.095 & 0.092 & 0.123 & 0.240 & 0.123 \\
#  &  & short & 0.053 & 0.055 & 0.055 & 0.055 & \textbf{0.051} & 0.072 & 0.066 & 0.065 & 0.081 & 0.082 & 0.081 \\
# \cline{2-14}
#  & D & short & 0.043 & 0.044 & 0.045 & 0.046 & \textbf{0.041} & 0.052 & 0.046 & 0.048 & 0.078 & 0.072 & 0.131 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & \textbf{0.063} & 0.076 & 0.082 & 0.087 & 0.066 & 0.068 & 0.069 & 0.068 & 0.193 & 0.468 & 0.245 \\
#  &  & medium & \textbf{0.067} & 0.076 & 0.082 & 0.087 & 0.067 & 0.072 & 0.071 & 0.069 & 0.154 & 0.390 & 0.206 \\
#  &  & short & 0.063 & 0.065 & 0.066 & 0.071 & \textbf{0.059} & 0.066 & 0.076 & 0.073 & 0.108 & 0.165 & 0.108 \\
# \cline{1-14} \cline{2-14}
# m4_daily & D & short & 0.023 & 0.021 & 0.021 & \textbf{0.021} & 0.021 & 0.030 & 0.023 & 0.023 & 0.023 & 0.024 & 0.026 \\
# \cline{1-14} \cline{2-14}
# m4_hourly & H & short & 0.030 & 0.025 & 0.020 & 0.021 & \textbf{0.011} & 0.133 & 0.039 & 0.040 & 0.034 & 0.041 & 0.040 \\
# \cline{1-14} \cline{2-14}
# m4_monthly & M & short & 0.094 & 0.094 & 0.094 & 0.095 & \textbf{0.067} & 0.184 & 0.102 & 0.113 & 0.098 & 0.098 & 0.126 \\
# \cline{1-14} \cline{2-14}
# m4_quarterly & Q & short & 0.078 & 0.077 & 0.078 & 0.079 & \textbf{0.062} & 0.083 & 0.083 & 0.083 & 0.082 & 0.079 & 0.099 \\
# \cline{1-14} \cline{2-14}
# m4_weekly & W & short & \textbf{0.037} & 0.038 & 0.038 & 0.041 & 0.042 & 0.062 & 0.040 & 0.049 & 0.050 & 0.053 & 0.073 \\
# \cline{1-14} \cline{2-14}
# m4_yearly & A & short & 0.118 & 0.121 & 0.128 & 0.129 & \textbf{0.091} & 0.113 & 0.117 & 0.110 & 0.130 & 0.115 & 0.138 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{4}{*}{m_dense} & D & short & 0.061 & 0.069 & 0.072 & 0.082 & \textbf{0.060} & 0.076 & 0.070 & 0.077 & 0.135 & 0.126 & 0.294 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & 0.165 & 0.170 & 0.146 & 0.198 & 0.127 & 0.130 & 0.120 & \textbf{0.115} & 0.270 & 1.430 & 0.552 \\
#  &  & medium & 0.160 & 0.157 & 0.134 & 0.155 & 0.127 & 0.118 & 0.127 & \textbf{0.114} & 0.255 & 1.210 & 0.479 \\
#  &  & short & 0.155 & \textbf{0.125} & 0.133 & 0.140 & 0.139 & 0.128 & 0.173 & 0.139 & 0.281 & 0.549 & 0.281 \\
# \cline{1-14} \cline{2-14}
# restaurant & D & short & 0.263 & 0.264 & 0.264 & 0.276 & \textbf{0.261} & 0.270 & 0.262 & 0.284 & 0.362 & 0.329 & 0.907 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{3}{*}{saugeen} & D & short & 0.373 & \textbf{0.338} & 0.354 & 0.339 & 0.408 & 0.572 & 0.408 & 0.419 & 0.564 & 0.669 & 0.754 \\
# \cline{2-14}
#  & M & short & \textbf{0.276} & 0.296 & 0.293 & 0.288 & 0.342 & 0.689 & 0.372 & 0.340 & 0.326 & 0.373 & 0.445 \\
# \cline{2-14}
#  & W & short & 0.395 & \textbf{0.363} & 0.372 & 0.364 & 0.601 & 0.397 & 0.484 & 0.491 & 0.549 & 0.734 & 0.855 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{8}{*}{solar} & \multirow[t]{3}{*}{10T} & long & \textbf{0.331} & 0.443 & 0.497 & 0.534 & 0.498 & 0.549 & 0.339 & 0.379 & 0.786 & 6.640 & 0.786 \\
#  &  & medium & \textbf{0.326} & 0.436 & 0.453 & 0.495 & 0.516 & 0.485 & 0.356 & 0.362 & 0.771 & 5.670 & 0.771 \\
#  &  & short & \textbf{0.458} & 0.511 & 0.498 & 0.488 & 0.804 & 0.933 & 1.370 & 0.618 & 0.860 & 2.360 & 0.860 \\
# \cline{2-14}
#  & D & short & \textbf{0.269} & 0.287 & 0.286 & 0.282 & 0.278 & 0.682 & 0.287 & 0.277 & 0.282 & 0.286 & 0.757 \\
# \cline{2-14}
#  & \multirow[t]{3}{*}{H} & long & \textbf{0.351} & 0.405 & 0.373 & 0.354 & 0.493 & 0.381 & 0.353 & 0.401 & 0.607 & 7.320 & 1.470 \\
#  &  & medium & \textbf{0.313} & 0.368 & 0.356 & 0.342 & 0.376 & 0.352 & 0.344 & 0.330 & 0.557 & 6.130 & 1.270 \\
#  &  & short & 0.336 & \textbf{0.298} & 0.303 & 0.313 & 0.406 & 0.389 & 0.340 & 0.367 & 0.628 & 2.330 & 0.628 \\
# \cline{2-14}
#  & W & short & 0.120 & 0.133 & 0.136 & 0.132 & 0.171 & 0.242 & 0.162 & \textbf{0.114} & 0.152 & 0.155 & 0.236 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{4}{*}{sz_taxi} & \multirow[t]{3}{*}{15T} & long & 0.242 & 0.248 & 0.245 & 0.240 & \textbf{0.227} & 0.286 & 0.281 & 0.241 & 0.398 & 0.629 & 0.554 \\
#  &  & medium & 0.230 & 0.244 & 0.246 & 0.240 & 0.229 & 0.210 & 0.220 & \textbf{0.206} & 0.351 & 0.529 & 0.454 \\
#  &  & short & 0.209 & 0.202 & 0.203 & 0.203 & \textbf{0.199} & 0.219 & 0.207 & 0.222 & 0.309 & 0.288 & 0.309 \\
# \cline{2-14}
#  & H & short & 0.140 & 0.136 & 0.137 & 0.137 & \textbf{0.135} & 0.139 & 0.144 & 0.144 & 0.170 & 0.232 & 0.229 \\
# \cline{1-14} \cline{2-14}
# temperature_rain & D & short & 0.569 & \textbf{0.538} & 0.544 & 0.548 & 0.586 & 0.682 & 0.644 & 0.592 & 0.694 & 0.761 & 1.630 \\
# \cline{1-14} \cline{2-14}
# \multirow[t]{3}{*}{us_births} & D & short & \textbf{0.016} & 0.026 & 0.028 & 0.037 & 0.019 & 0.028 & 0.025 & 0.016 & 0.074 & 0.075 & 0.144 \\
# \cline{2-14}
#  & M & short & 0.015 & 0.019 & 0.016 & 0.017 & 0.011 & 0.016 & 0.017 & 0.021 & \textbf{0.010} & 0.019 & 0.017 \\
# \cline{2-14}
#  & W & short & \textbf{0.011} & 0.013 & 0.013 & 0.014 & 0.013 & 0.017 & 0.015 & 0.019 & 0.018 & 0.018 & 0.022 \\
# \cline{1-14} \cline{2-14}
# \bottomrule
# \end{tabular}
# <style type="text/css">
# #T_5f250 th.col_heading.level1 {
#   transform: rotate(-45deg);
#   vertical-align: bottom;
#   padding-left: 10px;
#   padding-right: 10px;
#   height: 80px;
# }
# #T_5f250 th.col_heading.level0 {
#   text-align: center;
# }
# #T_5f250 th.row_heading {
#   transform: none;
# }
# #T_5f250_row0_col1, #T_5f250_row1_col2, #T_5f250_row2_col4, #T_5f250_row3_col1, #T_5f250_row4_col1, #T_5f250_row5_col1, #T_5f250_row6_col1, #T_5f250_row7_col9, #T_5f250_row8_col9, #T_5f250_row9_col9, #T_5f250_row10_col9, #T_5f250_row11_col0, #T_5f250_row12_col0, #T_5f250_row13_col6, #T_5f250_row14_col1, #T_5f250_row15_col0, #T_5f250_row16_col1, #T_5f250_row17_col0, #T_5f250_row18_col9, #T_5f250_row19_col9, #T_5f250_row20_col6, #T_5f250_row21_col8, #T_5f250_row22_col4, #T_5f250_row23_col4, #T_5f250_row24_col4, #T_5f250_row25_col1, #T_5f250_row26_col4, #T_5f250_row27_col4, #T_5f250_row28_col4, #T_5f250_row29_col4, #T_5f250_row30_col6, #T_5f250_row31_col1, #T_5f250_row32_col1, #T_5f250_row33_col0, #T_5f250_row34_col1, #T_5f250_row35_col3, #T_5f250_row36_col1, #T_5f250_row37_col3, #T_5f250_row38_col1, #T_5f250_row39_col1, #T_5f250_row40_col4, #T_5f250_row41_col2, #T_5f250_row42_col1, #T_5f250_row43_col1, #T_5f250_row44_col1, #T_5f250_row45_col1, #T_5f250_row46_col1, #T_5f250_row47_col4, #T_5f250_row48_col4, #T_5f250_row49_col4, #T_5f250_row50_col4, #T_5f250_row51_col4, #T_5f250_row52_col3, #T_5f250_row53_col1, #T_5f250_row54_col2, #T_5f250_row55_col4, #T_5f250_row56_col3, #T_5f250_row57_col1, #T_5f250_row58_col1, #T_5f250_row59_col1, #T_5f250_row60_col7, #T_5f250_row61_col0, #T_5f250_row62_col4, #T_5f250_row63_col4, #T_5f250_row64_col4, #T_5f250_row65_col4, #T_5f250_row66_col4, #T_5f250_row67_col4, #T_5f250_row68_col4, #T_5f250_row69_col4, #T_5f250_row70_col4, #T_5f250_row71_col0, #T_5f250_row72_col4, #T_5f250_row73_col4, #T_5f250_row74_col7, #T_5f250_row75_col7, #T_5f250_row76_col1, #T_5f250_row77_col6, #T_5f250_row78_col3, #T_5f250_row79_col3, #T_5f250_row80_col3, #T_5f250_row81_col0, #T_5f250_row82_col0, #T_5f250_row83_col3, #T_5f250_row84_col6, #T_5f250_row85_col3, #T_5f250_row86_col8, #T_5f250_row87_col1, #T_5f250_row88_col7, #T_5f250_row89_col4, #T_5f250_row90_col4, #T_5f250_row91_col4, #T_5f250_row92_col4, #T_5f250_row93_col1, #T_5f250_row94_col7, #T_5f250_row95_col8, #T_5f250_row96_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_5f250">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >model_type</th>
#       <th id="T_5f250_level0_col0" class="col_heading level0 col0" >Tabular Foundation Model</th>
#       <th id="T_5f250_level0_col1" class="col_heading level0 col1" colspan="4">Time-Series Foundation Model</th>
#       <th id="T_5f250_level0_col5" class="col_heading level0 col5" colspan="3">Deep Learning Time-Series Model</th>
#       <th id="T_5f250_level0_col8" class="col_heading level0 col8" colspan="3">Statistical Time-Series Model</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >display_model</th>
#       <th id="T_5f250_level1_col0" class="col_heading level1 col0" >TabPFN-TS</th>
#       <th id="T_5f250_level1_col1" class="col_heading level1 col1" >Chronos-Bolt Base</th>
#       <th id="T_5f250_level1_col2" class="col_heading level1 col2" >Chronos-Bolt Small</th>
#       <th id="T_5f250_level1_col3" class="col_heading level1 col3" >Chronos-Bolt Tiny</th>
#       <th id="T_5f250_level1_col4" class="col_heading level1 col4" >TimesFM2.0-500M</th>
#       <th id="T_5f250_level1_col5" class="col_heading level1 col5" >DeepAR</th>
#       <th id="T_5f250_level1_col6" class="col_heading level1 col6" >PatchTST</th>
#       <th id="T_5f250_level1_col7" class="col_heading level1 col7" >TFT</th>
#       <th id="T_5f250_level1_col8" class="col_heading level1 col8" >AutoARIMA</th>
#       <th id="T_5f250_level1_col9" class="col_heading level1 col9" >AutoTheta</th>
#       <th id="T_5f250_level1_col10" class="col_heading level1 col10" >Seasonal Naive</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Freq.</th>
#       <th class="index_name level2" >Term</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f250_level0_row0" class="row_heading level0 row0" rowspan="4">bitbrains_fast_storage</th>
#       <th id="T_5f250_level1_row0" class="row_heading level1 row0" rowspan="3">5T</th>
#       <th id="T_5f250_level2_row0" class="row_heading level2 row0" >long</th>
#       <td id="T_5f250_row0_col0" class="data row0 col0" >1.153</td>
#       <td id="T_5f250_row0_col1" class="data row0 col1" >0.948</td>
#       <td id="T_5f250_row0_col2" class="data row0 col2" >0.953</td>
#       <td id="T_5f250_row0_col3" class="data row0 col3" >0.994</td>
#       <td id="T_5f250_row0_col4" class="data row0 col4" >0.980</td>
#       <td id="T_5f250_row0_col5" class="data row0 col5" >7.330</td>
#       <td id="T_5f250_row0_col6" class="data row0 col6" >1.140</td>
#       <td id="T_5f250_row0_col7" class="data row0 col7" >1.210</td>
#       <td id="T_5f250_row0_col8" class="data row0 col8" >1.140</td>
#       <td id="T_5f250_row0_col9" class="data row0 col9" >1.610</td>
#       <td id="T_5f250_row0_col10" class="data row0 col10" >1.140</td>
#     </tr>
#     <tr>
#       <th id="T_5f250_level2_row1" class="row_heading level2 row1" >medium</th>
#       <td id="T_5f250_row1_col0" class="data row1 col0" >1.308</td>
#       <td id="T_5f250_row1_col1" class="data row1 col1" >1.062</td>
#       <td id="T_5f250_row1_col2" class="data row1 col2" >1.060</td>
#       <td id="T_5f250_row1_col3" class="data row1 col3" >1.115</td>
#       <td id="T_5f250_row1_col4" class="data row1 col4" >1.075</td>
#       <td id="T_5f250_row1_col5" class="data row1 col5" >8.500</td>
#       <td id="T_5f250_row1_col6" class="data row1 col6" >1.200</td>
#       <td id="T_5f250_row1_col7" class="data row1 col7" >1.380</td>
#       <td id="T_5f250_row1_col8" class="data row1 col8" >1.220</td>
#       <td id="T_5f250_row1_col9" class="data row1 col9" >1.420</td>
#       <td id="T_5f250_row1_col10" class="data row1 col10" >1.220</td>
#     </tr>
#     <tr>
#       <th id="T_5f250_level2_row2" class="row_heading level2 row2" >short</th>
#       <td id="T_5f250_row2_col0" class="data row2 col0" >0.998</td>
#       <td id="T_5f250_row2_col1" class="data row2 col1" >0.752</td>
#       <td id="T_5f250_row2_col2" class="data row2 col2" >0.770</td>
#       <td id="T_5f250_row2_col3" class="data row2 col3" >0.864</td>
#       <td id="T_5f250_row2_col4" class="data row2 col4" >0.731</td>
#       <td id="T_5f250_row2_col5" class="data row2 col5" >0.945</td>
#       <td id="T_5f250_row2_col6" class="data row2 col6" >0.973</td>
#       <td id="T_5f250_row2_col7" class="data row2 col7" >0.996</td>
#       <td id="T_5f250_row2_col8" class="data row2 col8" >1.140</td>
#       <td id="T_5f250_row2_col9" class="data row2 col9" >1.150</td>
#       <td id="T_5f250_row2_col10" class="data row2 col10" >1.140</td>
#     </tr>
#     <tr>
#       <th id="T_5f250_level1_row3" class="row_heading level1 row3" >H</th>
#       <th id="T_5f250_level2_row3" class="row_heading level2 row3" >short</th>
#       <td id="T_5f250_row3_col0" class="data row3 col0" >1.184</td>
#       <td id="T_5f250_row3_col1" class="data row3 col1" >1.070</td>
#       <td id="T_5f250_row3_col2" class="data row3 col2" >1.080</td>
#       <td id="T_5f250_row3_col3" class="data row3 col3" >1.150</td>
#       <td id="T_5f250_row3_col4" class="data row3 col4" >1.095</td>
#       <td id="T_5f250_row3_col5" class="data row3 col5" >6.060</
# <style type="text/css">
# #T_be2ef th.col_heading.level1 {
#   transform: rotate(-45deg);
#   vertical-align: bottom;
#   padding-left: 10px;
#   padding-right: 10px;
#   height: 80px;
# }
# #T_be2ef th.col_heading.level0 {
#   text-align: center;
# }
# #T_be2ef th.row_heading {
#   transform: none;
# }
# #T_be2ef_row0_col6, #T_be2ef_row1_col7, #T_be2ef_row2_col3, #T_be2ef_row3_col6, #T_be2ef_row4_col7, #T_be2ef_row5_col1, #T_be2ef_row6_col1, #T_be2ef_row7_col5, #T_be2ef_row8_col9, #T_be2ef_row9_col9, #T_be2ef_row10_col9, #T_be2ef_row11_col0, #T_be2ef_row12_col0, #T_be2ef_row13_col2, #T_be2ef_row14_col1, #T_be2ef_row15_col0, #T_be2ef_row16_col1, #T_be2ef_row17_col0, #T_be2ef_row18_col9, #T_be2ef_row19_col9, #T_be2ef_row20_col7, #T_be2ef_row21_col8, #T_be2ef_row22_col0, #T_be2ef_row23_col4, #T_be2ef_row24_col4, #T_be2ef_row25_col1, #T_be2ef_row26_col4, #T_be2ef_row27_col4, #T_be2ef_row28_col4, #T_be2ef_row29_col3, #T_be2ef_row30_col6, #T_be2ef_row31_col7, #T_be2ef_row32_col1, #T_be2ef_row33_col8, #T_be2ef_row34_col0, #T_be2ef_row35_col6, #T_be2ef_row36_col1, #T_be2ef_row37_col4, #T_be2ef_row38_col6, #T_be2ef_row39_col6, #T_be2ef_row40_col4, #T_be2ef_row41_col2, #T_be2ef_row42_col1, #T_be2ef_row43_col4, #T_be2ef_row44_col1, #T_be2ef_row45_col1, #T_be2ef_row46_col1, #T_be2ef_row47_col4, #T_be2ef_row48_col4, #T_be2ef_row49_col4, #T_be2ef_row50_col4, #T_be2ef_row51_col4, #T_be2ef_row52_col1, #T_be2ef_row53_col1, #T_be2ef_row54_col1, #T_be2ef_row55_col0, #T_be2ef_row56_col0, #T_be2ef_row57_col1, #T_be2ef_row58_col1, #T_be2ef_row59_col1, #T_be2ef_row60_col7, #T_be2ef_row61_col0, #T_be2ef_row62_col4, #T_be2ef_row63_col4, #T_be2ef_row64_col0, #T_be2ef_row65_col0, #T_be2ef_row66_col4, #T_be2ef_row67_col3, #T_be2ef_row68_col4, #T_be2ef_row69_col4, #T_be2ef_row70_col4, #T_be2ef_row71_col0, #T_be2ef_row72_col4, #T_be2ef_row73_col4, #T_be2ef_row74_col7, #T_be2ef_row75_col7, #T_be2ef_row76_col1, #T_be2ef_row77_col4, #T_be2ef_row78_col1, #T_be2ef_row79_col0, #T_be2ef_row80_col1, #T_be2ef_row81_col0, #T_be2ef_row82_col0, #T_be2ef_row83_col0, #T_be2ef_row84_col0, #T_be2ef_row85_col0, #T_be2ef_row86_col0, #T_be2ef_row87_col1, #T_be2ef_row88_col7, #T_be2ef_row89_col4, #T_be2ef_row90_col7, #T_be2ef_row91_col4, #T_be2ef_row92_col4, #T_be2ef_row93_col1, #T_be2ef_row94_col0, #T_be2ef_row95_col8, #T_be2ef_row96_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_be2ef">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >model_type</th>
#       <th id="T_be2ef_level0_col0" class="col_heading level0 col0" >Tabular Foundation Model</th>
#       <th id="T_be2ef_level0_col1" class="col_heading level0 col1" colspan="4">Time-Series Foundation Model</th>
#       <th id="T_be2ef_level0_col5" class="col_heading level0 col5" colspan="3">Deep Learning Time-Series Model</th>
#       <th id="T_be2ef_level0_col8" class="col_heading level0 col8" colspan="3">Statistical Time-Series Model</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >display_model</th>
#       <th id="T_be2ef_level1_col0" class="col_heading level1 col0" >TabPFN-TS</th>
#       <th id="T_be2ef_level1_col1" class="col_heading level1 col1" >Chronos-Bolt Base</th>
#       <th id="T_be2ef_level1_col2" class="col_heading level1 col2" >Chronos-Bolt Small</th>
#       <th id="T_be2ef_level1_col3" class="col_heading level1 col3" >Chronos-Bolt Tiny</th>
#       <th id="T_be2ef_level1_col4" class="col_heading level1 col4" >TimesFM2.0-500M</th>
#       <th id="T_be2ef_level1_col5" class="col_heading level1 col5" >DeepAR</th>
#       <th id="T_be2ef_level1_col6" class="col_heading level1 col6" >PatchTST</th>
#       <th id="T_be2ef_level1_col7" class="col_heading level1 col7" >TFT</th>
#       <th id="T_be2ef_level1_col8" class="col_heading level1 col8" >AutoARIMA</th>
#       <th id="T_be2ef_level1_col9" class="col_heading level1 col9" >AutoTheta</th>
#       <th id="T_be2ef_level1_col10" class="col_heading level1 col10" >Seasonal Naive</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="index_name level1" >Freq.</th>
#       <th class="index_name level2" >Term</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be2ef_level0_row0" class="row_heading level0 row0" rowspan="4">bitbrains_fast_storage</th>
#       <th id="T_be2ef_level1_row0" class="row_heading level1 row0" rowspan="3">5T</th>
#       <th id="T_be2ef_level2_row0" class="row_heading level2 row0" >long</th>
#       <td id="T_be2ef_row0_col0" class="data row0 col0" >0.885</td>
#       <td id="T_be2ef_row0_col1" class="data row0 col1" >0.748</td>
#       <td id="T_be2ef_row0_col2" class="data row0 col2" >0.753</td>
#       <td id="T_be2ef_row0_col3" class="data row0 col3" >0.750</td>
#       <td id="T_be2ef_row0_col4" class="data row0 col4" >0.908</td>
#       <td id="T_be2ef_row0_col5" class="data row0 col5" >1.010</td>
#       <td id="T_be2ef_row0_col6" class="data row0 col6" >0.669</td>
#       <td id="T_be2ef_row0_col7" class="data row0 col7" >0.734</td>
#       <td id="T_be2ef_row0_col8" class="data row0 col8" >1.290</td>
#       <td id="T_be2ef_row0_col9" class="data row0 col9" >1.360</td>
#       <td id="T_be2ef_row0_col10" class="data row0 col10" >1.290</td>
#     </tr>
#     <tr>
#       <th id="T_be2ef_level2_row1" class="row_heading level2 row1" >medium</th>
#       <td id="T_be2ef_row1_col0" class="data row1 col0" >0.949</td>
#       <td id="T_be2ef_row1_col1" class="data row1 col1" >0.755</td>
#       <td id="T_be2ef_row1_col2" class="data row1 col2" >0.867</td>
#       <td id="T_be2ef_row1_col3" class="data row1 col3" >0.814</td>
#       <td id="T_be2ef_row1_col4" class="data row1 col4" >0.881</td>
#       <td id="T_be2ef_row1_col5" class="data row1 col5" >0.990</td>
#       <td id="T_be2ef_row1_col6" class="data row1 col6" >0.642</td>
#       <td id="T_be2ef_row1_col7" class="data row1 col7" >0.610</td>
#       <td id="T_be2ef_row1_col8" class="data row1 col8" >1.270</td>
#       <td id="T_be2ef_row1_col9" class="data row1 col9" >1.450</td>
#       <td id="T_be2ef_row1_col10" class="data row1 col10" >1.270</td>
#     </tr>
#     <tr>
#       <th id="T_be2ef_level2_row2" class="row_heading level2 row2" >short</th>
#       <td id="T_be2ef_row2_col0" class="data row2 col0" >0.662</td>
#       <td id="T_be2ef_row2_col1" class="data row2 col1" >0.454</td>
#       <td id="T_be2ef_row2_col2" class="data row2 col2" >0.435</td>
#       <td id="T_be2ef_row2_col3" class="data row2 col3" >0.420</td>
#       <td id="T_be2ef_row2_col4" class="data row2 col4" >0.447</td>
#       <td id="T_be2ef_row2_col5" class="data row2 col5" >0.493</td>
#       <td id="T_be2ef_row2_col6" class="data row2 col6" >0.471</td>
#       <td id="T_be2ef_row2_col7" class="data row2 col7" >0.451</td>
#       <td id="T_be2ef_row2_col8" class="data row2 col8" >1.210</td>
#       <td id="T_be2ef_row2_col9" class="data row2 col9" >0.731</td>
#       <td id="T_be2ef_row2_col10" class="data row2 col10" >1.210</td>
#     </tr>
#     <tr>
#       <th id="T_be2ef_level1_row3" class="row_heading level1 row3" >H</th>
#       <th id="T_be2ef_level2_row3" class="row_heading level2 row3" >short</th>
#       <td id="T_be2ef_row3_col0" class="data row3 col0" >0.670</td>
#       <td id="T_be2ef_row3_col1" class="data row3 col1" >0.774</td>
#       <td id="T_be2ef_row3_col2" class="data row3 col2" >0.589</td>
#       <td id="T_be2ef_row3_col3" class="data row3 col3" >0.593</td>
#       <td id="T_be2ef_row3_col4" class="data row3 col4" >0.688</td>
#       <td id="T_be2ef_row3_col5" class="data row3 col5" >0.778</
